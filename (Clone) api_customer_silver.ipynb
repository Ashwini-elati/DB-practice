# %%
# %sql
SELECT *
FROM ingestion_autoloader.silver.customers
ORDER BY customer_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>name</th><th>email</th><th>city</th><th>_rescued_data</th><th>_ingestion_timestamp</th><th>_source_file</th></tr></thead><tbody><tr><td>104</td><td>Suresh Reddy</td><td>suresh@gmail.com</td><td>Delhi</td><td>null</td><td>2026-09-02T12:55:42.473Z</td><td>/Volumes/ingestion_autoloader/ingestion_demo/raw/input/Customers_002.csv</td></tr><tr><td>105</td><td>Meena Patel</td><td>meena@gmail.com</td><td>Mumbai</td><td>null</td><td>2026-09-02T12:55:42.473Z</td><td>/Volumes/ingestion_autoloader/ingestion_demo/raw/input/Customers_002.csv</td></tr><tr><td>106</td><td>David Brown</td><td>david@gmail.com</td><td>Pune</td><td>null</td><td>2026-09-02T12:55:42.473Z</td><td>/Volumes/ingestion_autoloader/ingestion_demo/raw/input/Customers_002.csv</td></tr><tr><td>107</td><td>Priya Singh</td><td>priya@gmail.com</td><td>Hyderabad</td><td>null</td><td>2026-09-02T12:55:42.473Z</td><td>/Volumes/ingestion_autoloader/ingestion_demo/raw/input/Customers_003.csv</td></tr><tr><td>108</td><td>Rahul Verma</td><td>rahul@gmail.com</td><td>Banglore</td><td>null</td><td>2026-09-02T12:55:42.473Z</td><td>/Volumes/ingestion_autoloader/ingestion_demo/raw/input/Customers_003.csv</td></tr><tr><td>109</td><td>Rahul Verma</td><td>rahul@gmail.com</td><td>Banglore</td><td>null</td><td>2026-09-02T12:55:42.473Z</td><td>/Volumes/ingestion_autoloader/ingestion_demo/raw/input/Customers_003.csv</td></tr><tr><td>110</td><td>null</td><td>missing@gmail.com</td><td>Chennai</td><td>null</td><td>2026-09-02T12:55:42.473Z</td><td>/Volumes/ingestion_autoloader/ingestion_demo/raw/input/Customers_003.csv</td></tr></tbody></table></div>

# %%
# %sql
SELECT *
FROM ingestion_autoloader.ingestion_demo.api_silver
ORDER BY customer_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>email</th><th>city</th><th>company_name</th><th>phone</th><th>website</th><th>_ingestion_timestamp</th><th>_source</th></tr></thead><tbody><tr><td>1</td><td>Leanne Graham</td><td>sincere@april.biz</td><td>{"street": "Kulas Light", "suite": "Apt. 556", "city": "Gwenborough", "zipcode": "92998-3874", "geo": {"lat": "-37.3159", "lng": "81.1496"}}</td><td>Romaguera-Crona</td><td>1-770-736-8031 x56442</td><td>hildegard.org</td><td>2026-09-02T16:46:02.561Z</td><td>jsonplaceholder_api</td></tr><tr><td>2</td><td>Ervin Howell</td><td>shanna@melissa.tv</td><td>{"street": "Victor Plains", "suite": "Suite 879", "city": "Wisokyburgh", "zipcode": "90566-7771", "geo": {"lat": "-43.9509", "lng": "-34.4618"}}</td><td>Deckow-Crist</td><td>010-692-6593 x09125</td><td>anastasia.net</td><td>2026-09-02T16:46:02.561Z</td><td>jsonplaceholder_api</td></tr><tr><td>3</td><td>Clementine Bauch</td><td>nathan@yesenia.net</td><td>{"street": "Douglas Extension", "suite": "Suite 847", "city": "McKenziehaven", "zipcode": "59590-4157", "geo": {"lat": "-68.6102", "lng": "-47.0653"}}</td><td>Romaguera-Jacobson</td><td>1-463-123-4447</td><td>ramiro.info</td><td>2026-09-02T16:46:02.561Z</td><td>jsonplaceholder_api</td></tr><tr><td>4</td><td>Patricia Lebsack</td><td>julianne.oconner@kory.org</td><td>{"street": "Hoeger Mall", "suite": "Apt. 692", "city": "South Elvis", "zipcode": "53919-4257", "geo": {"lat": "29.4572", "lng": "-164.2990"}}</td><td>Robel-Corkery</td><td>493-170-9623 x156</td><td>kale.biz</td><td>2026-09-02T16:46:02.561Z</td><td>jsonplaceholder_api</td></tr><tr><td>5</td><td>Chelsey Dietrich</td><td>lucio_hettinger@annie.ca</td><td>{"street": "Skiles Walks", "suite": "Suite 351", "city": "Roscoeview", "zipcode": "33263", "geo": {"lat": "-31.8129", "lng": "62.5342"}}</td><td>Keebler LLC</td><td>(254)954-1289</td><td>demarco.info</td><td>2026-09-02T16:46:02.561Z</td><td>jsonplaceholder_api</td></tr><tr><td>6</td><td>Mrs. Dennis Schulist</td><td>karley_dach@jasper.info</td><td>{"street": "Norberto Crossing", "suite": "Apt. 950", "city": "South Christy", "zipcode": "23505-1337", "geo": {"lat": "-71.4197", "lng": "71.7478"}}</td><td>Considine-Lockman</td><td>1-477-935-8478 x6430</td><td>ola.org</td><td>2026-09-02T16:46:02.561Z</td><td>jsonplaceholder_api</td></tr><tr><td>7</td><td>Kurtis Weissnat</td><td>telly.hoeger@billy.biz</td><td>{"street": "Rex Trail", "suite": "Suite 280", "city": "Howemouth", "zipcode": "58804-1099", "geo": {"lat": "24.8918", "lng": "21.8984"}}</td><td>Johns Group</td><td>210.067.6132</td><td>elvis.io</td><td>2026-09-02T16:46:02.561Z</td><td>jsonplaceholder_api</td></tr><tr><td>8</td><td>Nicholas Runolfsdottir V</td><td>sherwood@rosamond.me</td><td>{"street": "Ellsworth Summit", "suite": "Suite 729", "city": "Aliyaview", "zipcode": "45169", "geo": {"lat": "-14.3990", "lng": "-120.7677"}}</td><td>Abernathy Group</td><td>586.493.6943 x140</td><td>jacynthe.com</td><td>2026-09-02T16:46:02.561Z</td><td>jsonplaceholder_api</td></tr><tr><td>9</td><td>Glenna Reichert</td><td>chaim_mcdermott@dana.io</td><td>{"street": "Dayna Park", "suite": "Suite 449", "city": "Bartholomebury", "zipcode": "76495-3109", "geo": {"lat": "24.6463", "lng": "-168.8889"}}</td><td>Yost and Sons</td><td>(775)976-6794 x41206</td><td>conrad.com</td><td>2026-09-02T16:46:02.561Z</td><td>jsonplaceholder_api</td></tr><tr><td>10</td><td>Clementina DuBuque</td><td>rey.padberg@karina.biz</td><td>{"street": "Kattie Turnpike", "suite": "Suite 198", "city": "Lebsackbury", "zipcode": "31428-2261", "geo": {"lat": "-38.2386", "lng": "57.2232"}}</td><td>Hoeger LLC</td><td>024-648-3804</td><td>ambrose.net</td><td>2026-09-02T16:46:02.561Z</td><td>jsonplaceholder_api</td></tr></tbody></table></div>

# %%
from pyspark.sql import Row

api_test_data = [
    Row(customer_id=101, customer_name="Ravi Kumar", segment="Premium"),
    Row(customer_id=102, customer_name="John Smith", segment="Standard"),
    Row(customer_id=103, customer_name="Anita Sharma", segment="Premium"),
    Row(customer_id=104, customer_name="Suresh Reddy", segment="Standard"),
    Row(customer_id=105, customer_name="Meena Patel", segment="Premium"),
    Row(customer_id=106, customer_name="David Brown", segment="Standard"),
]

# %%
api_test_df = spark.createDataFrame(api_test_data)

display(api_test_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>segment</th></tr></thead><tbody><tr><td>101</td><td>Ravi Kumar</td><td>Premium</td></tr><tr><td>102</td><td>John Smith</td><td>Standard</td></tr><tr><td>103</td><td>Anita Sharma</td><td>Premium</td></tr><tr><td>104</td><td>Suresh Reddy</td><td>Standard</td></tr><tr><td>105</td><td>Meena Patel</td><td>Premium</td></tr><tr><td>106</td><td>David Brown</td><td>Standard</td></tr></tbody></table></div>

# %%
(
    api_test_df.write
    .format("delta")
    .mode("overwrite")
    .saveAsTable(
        "ingestion_autoloader.ingestion_demo.api_customer_silver"
    )
)

# %%
# %sql
SELECT *
FROM ingestion_autoloader.ingestion_demo.api_customer_silver;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>segment</th></tr></thead><tbody><tr><td>101</td><td>Ravi Kumar</td><td>Premium</td></tr><tr><td>102</td><td>John Smith</td><td>Standard</td></tr><tr><td>103</td><td>Anita Sharma</td><td>Premium</td></tr><tr><td>104</td><td>Suresh Reddy</td><td>Standard</td></tr><tr><td>105</td><td>Meena Patel</td><td>Premium</td></tr><tr><td>106</td><td>David Brown</td><td>Standard</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import col

customer_gold = (
    api_test_df
    .select(
        col("customer_id"),
        col("name").alias("customer_name"),
        col("email"),
        col("city")
    )
)
